# %%
import pandas as pd
import numpy as np

# %%
jobs = pd.read_csv("./data/updated_jobs.csv")

# %%
jobs.head()
# Out:
#         job_title_short                                          job_title  \
# 0  Senior Data Engineer  Senior Clinical Data Engineer / Principal Clin...
# 1          Data Analyst                                       Data Analyst
# 2         Data Engineer  Data Engineer/Scientist/Analyst, Mid or Senior...
# 3         Data Engineer  LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4         Data Engineer                             Data Engineer- Sr Jobs
#
#                    job_location             job_via job_schedule_type  \
# 0                 Watertown, CT     via Work Nearby         Full-time
# 1  Guadalajara, Jalisco, Mexico    via BeBee México         Full-time
# 2               Berlin, Germany        via LinkedIn         Full-time
# 3               San Antonio, TX   via Diversity.com         Full-time
# 4                Washington, DC  via Clearance Jobs         Full-time
#
#    job_work_from_home       search_location      job_posted_date  \
# ...

# %%
jobs.tail()
# Out:
#           job_title_short                                          job_title  \
# 785736  Software Engineer                                    DevOps Engineer
# 785737       Data Analyst                                   CRM Data Analyst
# 785738   Business Analyst                     Commercial Analyst - Start Now
# 785739      Data Engineer  Principal Associate, Data Engineer (Remote-Eli...
# 785740  Software Engineer                                 AWS System Analyst
#
#                                job_location                    job_via  \
# 785736                            Singapura        melalui Trabajo.org
# 785737                   Bad Rodach, Jerman  melalui BeBee Deutschland
# 785738                             Malaysia           melalui Ricebowl
# 785739  Newark, New Jersey, Amerika Serikat        melalui Recruit.net
# 785740                                India             melalui Trigyn
#
#        job_schedule_type  job_work_from_home search_location  \
# ...

# %%
jobs.shape
# Out:
# (785741, 17)

# %%
jobs.columns
# Out:
# Index(['job_title_short', 'job_title', 'job_location', 'job_via',
#        'job_schedule_type', 'job_work_from_home', 'search_location',
#        'job_posted_date', 'job_no_degree_mention', 'job_health_insurance',
#        'job_country', 'salary_rate', 'salary_year_avg', 'salary_hour_avg',
#        'company_name', 'job_skills', 'job_type_skills'],
#       dtype='object')

# %%
jobs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 785741 entries, 0 to 785740
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   job_title_short        785741 non-null  object
#  1   job_title              785740 non-null  object
#  2   job_location           784696 non-null  object
#  3   job_via                785733 non-null  object
#  4   job_schedule_type      773074 non-null  object
#  5   job_work_from_home     785741 non-null  bool
#  6   search_location        785741 non-null  object
#  7   job_posted_date        785741 non-null  object
#  8   job_no_degree_mention  785741 non-null  bool
#  9   job_health_insurance   785741 non-null  bool
#  10  job_country            785692 non-null  object
#  11  salary_rate            33067 non-null   object
#  12  salary_year_avg        22003 non-null   float64
#  13  salary_hour_avg        10662 non-null   float64
# ...

# %%
jobs["job_posted_date"] = pd.to_datetime(jobs["job_posted_date"])

# %%
jobs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 785741 entries, 0 to 785740
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   job_title_short        785741 non-null  object
#  1   job_title              785740 non-null  object
#  2   job_location           784696 non-null  object
#  3   job_via                785733 non-null  object
#  4   job_schedule_type      773074 non-null  object
#  5   job_work_from_home     785741 non-null  bool
#  6   search_location        785741 non-null  object
#  7   job_posted_date        785741 non-null  datetime64[ns]
#  8   job_no_degree_mention  785741 non-null  bool
#  9   job_health_insurance   785741 non-null  bool
#  10  job_country            785692 non-null  object
#  11  salary_rate            33067 non-null   object
#  12  salary_year_avg        22003 non-null   float64
#  13  salary_hour_avg        10662 non-null   float64
# ...

# %%
jobs.head()
# Out:
#         job_title_short                                          job_title  \
# 0  Senior Data Engineer  Senior Clinical Data Engineer / Principal Clin...
# 1          Data Analyst                                       Data Analyst
# 2         Data Engineer  Data Engineer/Scientist/Analyst, Mid or Senior...
# 3         Data Engineer  LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4         Data Engineer                             Data Engineer- Sr Jobs
#
#                    job_location             job_via job_schedule_type  \
# 0                 Watertown, CT     via Work Nearby         Full-time
# 1  Guadalajara, Jalisco, Mexico    via BeBee México         Full-time
# 2               Berlin, Germany        via LinkedIn         Full-time
# 3               San Antonio, TX   via Diversity.com         Full-time
# 4                Washington, DC  via Clearance Jobs         Full-time
#
#    job_work_from_home       search_location     job_posted_date  \
# ...

# %%
jobs.sample(40)
# Out:
#               job_title_short  \
# 722087           Data Analyst
# 46999   Senior Data Scientist
# 631328  Senior Data Scientist
# 663256       Business Analyst
# 482508    Senior Data Analyst
# 122910           Data Analyst
# 165548           Data Analyst
# 284043         Data Scientist
# 619020         Data Scientist
# 772651         Data Scientist
# 752348           Data Analyst
# 549804           Data Analyst
# 129542         Data Scientist
# 665295          Data Engineer
# 619397         Data Scientist
# 512622           Data Analyst
# 687348         Cloud Engineer
# 391474          Data Engineer
# 719061       Business Analyst
# 33315           Data Engineer
# 5395             Data Analyst
# 474789       Business Analyst
# 654930         Data Scientist
# 534931          Data Engineer
# 681960           Data Analyst
# 59287           Data Engineer
# 486800   Senior Data Engineer
# 153140         Data Scientist
# 480429          Data Engineer
# 216453       Business Analyst
# ...

# %%
jobs.isnull().sum()
# Out:
# job_title_short               0
# job_title                     1
# job_location               1045
# job_via                       8
# job_schedule_type         12667
# job_work_from_home            0
# search_location               0
# job_posted_date               0
# job_no_degree_mention         0
# job_health_insurance          0
# job_country                  49
# salary_rate              752674
# salary_year_avg          763738
# salary_hour_avg          775079
# company_name                 18
# job_skills               117037
# job_type_skills          117037
# dtype: int64

# %%
jobs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 785741 entries, 0 to 785740
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   job_title_short        785741 non-null  object
#  1   job_title              785740 non-null  object
#  2   job_location           784696 non-null  object
#  3   job_via                785733 non-null  object
#  4   job_schedule_type      773074 non-null  object
#  5   job_work_from_home     785741 non-null  bool
#  6   search_location        785741 non-null  object
#  7   job_posted_date        785741 non-null  datetime64[ns]
#  8   job_no_degree_mention  785741 non-null  bool
#  9   job_health_insurance   785741 non-null  bool
#  10  job_country            785692 non-null  object
#  11  salary_rate            33067 non-null   object
#  12  salary_year_avg        22003 non-null   float64
#  13  salary_hour_avg        10662 non-null   float64
# ...

# %%
jobs = jobs.dropna(subset=["salary_hour_avg"])

# %%
jobs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10662 entries, 43 to 785492
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   job_title_short        10662 non-null  object
#  1   job_title              10662 non-null  object
#  2   job_location           10586 non-null  object
#  3   job_via                10654 non-null  object
#  4   job_schedule_type      10536 non-null  object
#  5   job_work_from_home     10662 non-null  bool
#  6   search_location        10662 non-null  object
#  7   job_posted_date        10662 non-null  datetime64[ns]
#  8   job_no_degree_mention  10662 non-null  bool
#  9   job_health_insurance   10662 non-null  bool
#  10  job_country            10662 non-null  object
#  11  salary_rate            10662 non-null  object
#  12  salary_year_avg        0 non-null      float64
#  13  salary_hour_avg        10662 non-null  float64
# ...

# %%
jobs.sample(50)
# Out:
#                   job_title_short  \
# 421923              Data Engineer
# 443496               Data Analyst
# 613462             Data Scientist
# 175581           Business Analyst
# 11631       Senior Data Scientist
# 381248               Data Analyst
# 621518               Data Analyst
# 219610           Business Analyst
# 39507               Data Engineer
# 613245              Data Engineer
# 200545               Data Analyst
# 138604             Data Scientist
# 299924        Senior Data Analyst
# 354024             Data Scientist
# 458938             Data Scientist
# 674688  Machine Learning Engineer
# 738872        Senior Data Analyst
# 472322           Business Analyst
# 760963               Data Analyst
# 306001       Senior Data Engineer
# 56196       Senior Data Scientist
# 550231               Data Analyst
# 35146              Data Scientist
# 218649             Data Scientist
# 702023          Software Engineer
# 375730               Data Analyst
# ...

# %%
null_salary = jobs[jobs.isnull().any(axis=1)].copy()

# %%
null_salary
# Out:
#              job_title_short  \
# 43      Senior Data Engineer
# 51      Senior Data Engineer
# 253            Data Engineer
# 294             Data Analyst
# 340             Data Analyst
# ...                      ...
# 784068         Data Engineer
# 784267  Senior Data Engineer
# 785111  Senior Data Engineer
# 785476        Data Scientist
# 785492        Data Scientist
#
#                                                 job_title        job_location  \
# 43      Sr SQL Database Engineer with Data Warehouse /...                 NaN
# 51                                   Senior Data Engineer            Anywhere
# 253                                         Data Engineer            Anywhere
# 294                                 Business/Data Analyst        Hartford, CT
# 340     23-00059 BI Data Analysts + Media experience -...          California
# ...                                                   ...                 ...
# ...

# %%
null_salary.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10662 entries, 43 to 785492
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   job_title_short        10662 non-null  object
#  1   job_title              10662 non-null  object
#  2   job_location           10586 non-null  object
#  3   job_via                10654 non-null  object
#  4   job_schedule_type      10536 non-null  object
#  5   job_work_from_home     10662 non-null  bool
#  6   search_location        10662 non-null  object
#  7   job_posted_date        10662 non-null  datetime64[ns]
#  8   job_no_degree_mention  10662 non-null  bool
#  9   job_health_insurance   10662 non-null  bool
#  10  job_country            10662 non-null  object
#  11  salary_rate            10662 non-null  object
#  12  salary_year_avg        0 non-null      float64
#  13  salary_hour_avg        10662 non-null  float64
# ...

# %%
null_salary.isnull().sum()
# Out:
# job_title_short              0
# job_title                    0
# job_location                76
# job_via                      8
# job_schedule_type          126
# job_work_from_home           0
# search_location              0
# job_posted_date              0
# job_no_degree_mention        0
# job_health_insurance         0
# job_country                  0
# salary_rate                  0
# salary_year_avg          10662
# salary_hour_avg              0
# company_name                 0
# job_skills                1372
# job_type_skills           1372
# dtype: int64

# %%
null_salary["salary_year_avg"] = null_salary["salary_year_avg"].fillna(jobs["salary_year_avg"].mean())

# %%
null_salary.head()
# Out:
#           job_title_short                                          job_title  \
# 43   Senior Data Engineer  Sr SQL Database Engineer with Data Warehouse /...
# 51   Senior Data Engineer                               Senior Data Engineer
# 253         Data Engineer                                      Data Engineer
# 294          Data Analyst                              Business/Data Analyst
# 340          Data Analyst  23-00059 BI Data Analysts + Media experience -...
#
#      job_location       job_via         job_schedule_type  job_work_from_home  \
# 43            NaN  via LinkedIn                Contractor               False
# 51       Anywhere  via LinkedIn                Contractor                True
# 253      Anywhere    via Upwork  Contractor and Temp work                True
# 294  Hartford, CT      via Dice                Contractor               False
# 340    California  via LinkedIn                Contractor               False
#
# ...

# %%
jobs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10662 entries, 43 to 785492
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   job_title_short        10662 non-null  object
#  1   job_title              10662 non-null  object
#  2   job_location           10586 non-null  object
#  3   job_via                10654 non-null  object
#  4   job_schedule_type      10536 non-null  object
#  5   job_work_from_home     10662 non-null  bool
#  6   search_location        10662 non-null  object
#  7   job_posted_date        10662 non-null  datetime64[ns]
#  8   job_no_degree_mention  10662 non-null  bool
#  9   job_health_insurance   10662 non-null  bool
#  10  job_country            10662 non-null  object
#  11  salary_rate            10662 non-null  object
#  12  salary_year_avg        0 non-null      float64
#  13  salary_hour_avg        10662 non-null  float64
# ...

# %%
jobs.sample(20)
# Out:
#               job_title_short  \
# 159839           Data Analyst
# 522421       Business Analyst
# 29682   Senior Data Scientist
# 164132          Data Engineer
# 454712          Data Engineer
# 473680           Data Analyst
# 166093          Data Engineer
# 412081         Data Scientist
# 556104    Senior Data Analyst
# 284542         Data Scientist
# 121087         Data Scientist
# 702546   Senior Data Engineer
# 159233           Data Analyst
# 352266          Data Engineer
# 660778         Cloud Engineer
# 69497     Senior Data Analyst
# 137539         Data Scientist
# 42242          Data Scientist
# 126067          Data Engineer
# 701304           Data Analyst
#
#                                                 job_title  \
# 159839                                       Data Analyst
# 522421                              Sr. Financial Analyst
# 29682   Senior Data Scientist - Algorithm design & sys...
# 164132                                      Data Engineer
# ...

# %%
jobs["salary_year_avg"] = jobs["salary_year_avg"].fillna(jobs["salary_year_avg"].mean())

# %%
jobs.sample(20)
# Out:
#               job_title_short  \
# 766112          Data Engineer
# 406087      Software Engineer
# 417309           Data Analyst
# 655735         Data Scientist
# 448956           Data Analyst
# 649760         Data Scientist
# 615483  Senior Data Scientist
# 247556      Software Engineer
# 161447   Senior Data Engineer
# 425033           Data Analyst
# 104234           Data Analyst
# 590301         Data Scientist
# 243431          Data Engineer
# 744078   Senior Data Engineer
# 317092          Data Engineer
# 779793           Data Analyst
# 264807           Data Analyst
# 172531          Data Engineer
# 281058          Data Engineer
# 494958         Data Scientist
#
#                                                 job_title  \
# 766112                             Data Engineer (Remote)
# 406087                                    Junior Engineer
# 417309                             CRM Analytics Engineer
# 655735            Manager, Statistical Data Sciences Lead
# ...

# %%
jobs = jobs.dropna(subset=["salary_year_avg"])

# %%
jobs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 22003 entries, 28 to 785692
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   job_title_short        22003 non-null  object
#  1   job_title              22003 non-null  object
#  2   job_location           21723 non-null  object
#  3   job_via                22003 non-null  object
#  4   job_schedule_type      21987 non-null  object
#  5   job_work_from_home     22003 non-null  bool
#  6   search_location        22003 non-null  object
#  7   job_posted_date        22003 non-null  object
#  8   job_no_degree_mention  22003 non-null  bool
#  9   job_health_insurance   22003 non-null  bool
#  10  job_country            22003 non-null  object
#  11  salary_rate            22003 non-null  object
#  12  salary_year_avg        22003 non-null  float64
#  13  salary_hour_avg        0 non-null      float64
# ...

# %%
null_salary = jobs[jobs.isnull().any(axis=1)].copy()

# %%
null_salary.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 22003 entries, 28 to 785692
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   job_title_short        22003 non-null  object
#  1   job_title              22003 non-null  object
#  2   job_location           21723 non-null  object
#  3   job_via                22003 non-null  object
#  4   job_schedule_type      21987 non-null  object
#  5   job_work_from_home     22003 non-null  bool
#  6   search_location        22003 non-null  object
#  7   job_posted_date        22003 non-null  object
#  8   job_no_degree_mention  22003 non-null  bool
#  9   job_health_insurance   22003 non-null  bool
#  10  job_country            22003 non-null  object
#  11  salary_rate            22003 non-null  object
#  12  salary_year_avg        22003 non-null  float64
#  13  salary_hour_avg        0 non-null      float64
# ...

# %%
null_salary.isnull().sum()
# Out:
# job_title_short              0
# job_title                    0
# job_location               280
# job_via                      0
# job_schedule_type           16
# job_work_from_home           0
# search_location              0
# job_posted_date              0
# job_no_degree_mention        0
# job_health_insurance         0
# job_country                  0
# salary_rate                  0
# salary_year_avg              0
# salary_hour_avg          22003
# company_name                 0
# job_skills                1833
# job_type_skills           1833
# dtype: int64

# %%
null_salary["salary_hour_avg"] = null_salary["salary_hour_avg"].fillna(null_salary["salary_year_avg"]/1920)

# %%
null_salary.head()
# Out:
#     job_title_short                                job_title  \
# 28   Data Scientist                      CRM Data Specialist
# 77    Data Engineer                            Data Engineer
# 92    Data Engineer  Remote - Data Engineer - Permanent - W2
# 100  Data Scientist  Data Scientist, Risk Data Mining - USDS
# 109    Data Analyst    Senior Supply Chain Analytics Analyst
#
#                                 job_location          job_via  \
# 28   San José Province, San José, Costa Rica  via Ai-Jobs.net
# 77                             Arlington, VA     via LinkedIn
# 92                                  Anywhere     via LinkedIn
# 100                        Mountain View, CA     via LinkedIn
# 109                                 Anywhere       via Get.It
#
#     job_schedule_type  job_work_from_home            search_location  \
# 28          Full-time               False                 Costa Rica
# 77          Full-time               False                      Sudan
# ...

# %%
null_salary["salary_hour_avg"] = null_salary["salary_hour_avg"].round(2)

# %%
null_salary.head()
# Out:
#     job_title_short                                job_title  \
# 28   Data Scientist                      CRM Data Specialist
# 77    Data Engineer                            Data Engineer
# 92    Data Engineer  Remote - Data Engineer - Permanent - W2
# 100  Data Scientist  Data Scientist, Risk Data Mining - USDS
# 109    Data Analyst    Senior Supply Chain Analytics Analyst
#
#                                 job_location          job_via  \
# 28   San José Province, San José, Costa Rica  via Ai-Jobs.net
# 77                             Arlington, VA     via LinkedIn
# 92                                  Anywhere     via LinkedIn
# 100                        Mountain View, CA     via LinkedIn
# 109                                 Anywhere       via Get.It
#
#     job_schedule_type  job_work_from_home            search_location  \
# 28          Full-time               False                 Costa Rica
# 77          Full-time               False                      Sudan
# ...

# %%
jobs.update(null_salary)

# %%
jobs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 22003 entries, 28 to 785692
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   job_title_short        22003 non-null  object
#  1   job_title              22003 non-null  object
#  2   job_location           21723 non-null  object
#  3   job_via                22003 non-null  object
#  4   job_schedule_type      21987 non-null  object
#  5   job_work_from_home     22003 non-null  bool
#  6   search_location        22003 non-null  object
#  7   job_posted_date        22003 non-null  object
#  8   job_no_degree_mention  22003 non-null  bool
#  9   job_health_insurance   22003 non-null  bool
#  10  job_country            22003 non-null  object
#  11  salary_rate            22003 non-null  object
#  12  salary_year_avg        22003 non-null  float64
#  13  salary_hour_avg        22003 non-null  float64
# ...

# %%
jobs.isnull().sum()
# Out:
# job_title_short             0
# job_title                   0
# job_location              280
# job_via                     0
# job_schedule_type          16
# job_work_from_home          0
# search_location             0
# job_posted_date             0
# job_no_degree_mention       0
# job_health_insurance        0
# job_country                 0
# salary_rate                 0
# salary_year_avg             0
# salary_hour_avg             0
# company_name                0
# job_skills               1833
# job_type_skills          1833
# dtype: int64

# %%
jobs["job_skills"] = jobs["job_skills"].ffill()

# %%
jobs["job_type_skills"] = jobs["job_type_skills"].bfill()

# %%
jobs.isnull().sum()
# Out:
# job_title_short            0
# job_title                  0
# job_location             280
# job_via                    0
# job_schedule_type         16
# job_work_from_home         0
# search_location            0
# job_posted_date            0
# job_no_degree_mention      0
# job_health_insurance       0
# job_country                0
# salary_rate                0
# salary_year_avg            0
# salary_hour_avg            0
# company_name               0
# job_skills                 0
# job_type_skills            0
# dtype: int64

# %%
jobs.dropna(subset=["job_location", "job_schedule_type"], inplace=True)

# %%
jobs.isnull().sum()
# Out:
# job_title_short          0
# job_title                0
# job_location             0
# job_via                  0
# job_schedule_type        0
# job_work_from_home       0
# search_location          0
# job_posted_date          0
# job_no_degree_mention    0
# job_health_insurance     0
# job_country              0
# salary_rate              0
# salary_year_avg          0
# salary_hour_avg          0
# company_name             0
# job_skills               0
# job_type_skills          0
# dtype: int64

# %%
jobs.to_csv("./data/updated_jobs.csv")

# %%
jobs = pd.read_csv("./data/updated_jobs.csv")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 jobs = pd.read_csv("./data/updated_jobs.csv")
#
# NameError: name 'pd' is not defined

# %%
jobs.head()
# Out:
#    Unnamed: 0 job_title_short                                job_title  \
# 0          28  Data Scientist                      CRM Data Specialist
# 1          77   Data Engineer                            Data Engineer
# 2          92   Data Engineer  Remote - Data Engineer - Permanent - W2
# 3         100  Data Scientist  Data Scientist, Risk Data Mining - USDS
# 4         109    Data Analyst    Senior Supply Chain Analytics Analyst
#
#                               job_location          job_via job_schedule_type  \
# 0  San José Province, San José, Costa Rica  via Ai-Jobs.net         Full-time
# 1                            Arlington, VA     via LinkedIn         Full-time
# 2                                 Anywhere     via LinkedIn         Full-time
# 3                        Mountain View, CA     via LinkedIn         Full-time
# 4                                 Anywhere       via Get.It         Full-time
#
# ...

# %%
jobs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21707 entries, 0 to 21706
# Data columns (total 18 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Unnamed: 0             21707 non-null  int64
#  1   job_title_short        21707 non-null  object
#  2   job_title              21707 non-null  object
#  3   job_location           21707 non-null  object
#  4   job_via                21707 non-null  object
#  5   job_schedule_type      21707 non-null  object
#  6   job_work_from_home     21707 non-null  bool
#  7   search_location        21707 non-null  object
#  8   job_posted_date        21707 non-null  object
#  9   job_no_degree_mention  21707 non-null  bool
#  10  job_health_insurance   21707 non-null  bool
#  11  job_country            21707 non-null  object
#  12  salary_rate            21707 non-null  object
#  13  salary_year_avg        21707 non-null  float64
# ...

# %%
jobs.dropna()
# Out:
#        Unnamed: 0 job_title_short  \
# 0              28  Data Scientist
# 1              77   Data Engineer
# 2              92   Data Engineer
# 3             100  Data Scientist
# 4             109    Data Analyst
# ...           ...             ...
# 21702      785624   Data Engineer
# 21703      785641   Data Engineer
# 21704      785648  Data Scientist
# 21705      785682  Data Scientist
# 21706      785692  Data Scientist
#
#                                                job_title  \
# 0                                    CRM Data Specialist
# 1                                          Data Engineer
# 2                Remote - Data Engineer - Permanent - W2
# 3                Data Scientist, Risk Data Mining - USDS
# 4                  Senior Supply Chain Analytics Analyst
# ...                                                  ...
# 21702                   Data Analytics Engineer (Hybrid)
# 21703                                      Data Engineer
# ...

# %%
jobs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21707 entries, 0 to 21706
# Data columns (total 18 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Unnamed: 0             21707 non-null  int64
#  1   job_title_short        21707 non-null  object
#  2   job_title              21707 non-null  object
#  3   job_location           21707 non-null  object
#  4   job_via                21707 non-null  object
#  5   job_schedule_type      21707 non-null  object
#  6   job_work_from_home     21707 non-null  bool
#  7   search_location        21707 non-null  object
#  8   job_posted_date        21707 non-null  object
#  9   job_no_degree_mention  21707 non-null  bool
#  10  job_health_insurance   21707 non-null  bool
#  11  job_country            21707 non-null  object
#  12  salary_rate            21707 non-null  object
#  13  salary_year_avg        21707 non-null  float64
# ...

# %%
jobs["job_posted_date"] = pd.to_datetime(jobs["job_posted_date"])

# %%
jobs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21707 entries, 0 to 21706
# Data columns (total 18 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Unnamed: 0             21707 non-null  int64
#  1   job_title_short        21707 non-null  object
#  2   job_title              21707 non-null  object
#  3   job_location           21707 non-null  object
#  4   job_via                21707 non-null  object
#  5   job_schedule_type      21707 non-null  object
#  6   job_work_from_home     21707 non-null  bool
#  7   search_location        21707 non-null  object
#  8   job_posted_date        21707 non-null  datetime64[ns]
#  9   job_no_degree_mention  21707 non-null  bool
#  10  job_health_insurance   21707 non-null  bool
#  11  job_country            21707 non-null  object
#  12  salary_rate            21707 non-null  object
#  13  salary_year_avg        21707 non-null  float64
# ...

# %%
jobs.duplicated().sum()
# Out:
# np.int64(0)

# %%
jobs[jobs.duplicated(subset=["job_skills"])]
# Out:
#        Unnamed: 0            job_title_short  \
# 11            339              Data Engineer
# 12            380              Data Engineer
# 22            654              Data Engineer
# 38           1042  Machine Learning Engineer
# 50           1357              Data Engineer
# ...           ...                        ...
# 21697      785340      Senior Data Scientist
# 21699      785488             Data Scientist
# 21700      785515               Data Analyst
# 21703      785641              Data Engineer
# 21704      785648             Data Scientist
#
#                                                job_title  \
# 11     Global Market Leading Energy Firm - Staff Data...
# 12                               Snaplogic Data Engineer
# 22     Lead Data Engineer (DataStage) (Need only loca...
# 38                        Head of AML Operations (m/f/d)
# 50                 Data Engineer, Analytics (Generalist)
# ...                                                  ...
# ...

# %%
def taxes(salary_year_avg):
    if salary_year_avg <= 30000:
        return "Low"
    elif salary_year_avg<=80000:
        return "Mid"
    else:
        return "High"

# %%
jobs["tax_class"] = jobs["salary_year_avg"].apply(taxes)

# %%
jobs.head()
# Out:
#    Unnamed: 0 job_title_short                                job_title  \
# 0          28  Data Scientist                      CRM Data Specialist
# 1          77   Data Engineer                            Data Engineer
# 2          92   Data Engineer  Remote - Data Engineer - Permanent - W2
# 3         100  Data Scientist  Data Scientist, Risk Data Mining - USDS
# 4         109    Data Analyst    Senior Supply Chain Analytics Analyst
#
#                               job_location          job_via job_schedule_type  \
# 0  San José Province, San José, Costa Rica  via Ai-Jobs.net         Full-time
# 1                            Arlington, VA     via LinkedIn         Full-time
# 2                                 Anywhere     via LinkedIn         Full-time
# 3                        Mountain View, CA     via LinkedIn         Full-time
# 4                                 Anywhere       via Get.It         Full-time
#
# ...

# %%
jobs.groupby("job_country").agg({
    "salary_year_avg": ["mean", "max", "min"]
})
# Out:
#             salary_year_avg
#                        mean       max      min
# job_country
# Albania        79472.500000  157500.0  43200.0
# Algeria        44550.000000   45000.0  44100.0
# Argentina     105212.343750  222000.0  45000.0
# Armenia        78757.000000  128682.0  45000.0
# Australia     118987.574324  257500.0  20000.0
# ...                     ...       ...      ...
# Uruguay        69333.333333  100500.0  50000.0
# Uzbekistan     30750.000000   30750.0  30750.0
# Vietnam        90927.236364  200000.0  28000.0
# Zambia         90670.000000   90670.0  90670.0
# Zimbabwe       67056.666667   90670.0  47500.0
#
# [108 rows x 3 columns]

# %%
jobs.reset_index()
# Out:
#        index  Unnamed: 0 job_title_short  \
# 0          0          28  Data Scientist
# 1          1          77   Data Engineer
# 2          2          92   Data Engineer
# 3          3         100  Data Scientist
# 4          4         109    Data Analyst
# ...      ...         ...             ...
# 21702  21702      785624   Data Engineer
# 21703  21703      785641   Data Engineer
# 21704  21704      785648  Data Scientist
# 21705  21705      785682  Data Scientist
# 21706  21706      785692  Data Scientist
#
#                                                job_title  \
# 0                                    CRM Data Specialist
# 1                                          Data Engineer
# 2                Remote - Data Engineer - Permanent - W2
# 3                Data Scientist, Risk Data Mining - USDS
# 4                  Senior Supply Chain Analytics Analyst
# ...                                                  ...
# 21702                   Data Analytics Engineer (Hybrid)
# ...

# %%
jobs.groupby("job_title")["salary_year_avg"].agg(["min", "mean", "max"])
# Out:
#                                                          min      mean  \
# job_title
# #10049 - Sr. Data Scientist                         147500.0  147500.0
# #10128 - Data Analytics Roadmap Manager             165000.0  165000.0
# #10294#1-Data Architect ( ETL , DevOps, data mi...  165000.0  165000.0
# #10965 Junior Data Analyst                           57500.0   57500.0
# #569 Data Engineer Jr.                               97444.0   97444.0
# ...                                                      ...       ...
# senior analyst - data management .                  115000.0  115000.0
# シニアビジネスインテリジェンスエンジニア | Sr. Business Intelligenc...   79200.0   79200.0
# 機械学習エンジニア（Machine Learning Engineer）                190000.0  190000.0
# 財務・経営企画/Business Intelligence Engineer, Japan O...   79200.0   79200.0
# 🦸Research Engineer/ Data Scientist                  175000.0  175000.0
#
#                                                          max
# job_title
# ...

# %%
jobs["company_name"].value_counts()
# Out:
# company_name
# Jobot                                       335
# Capital One                                 281
# Booz Allen Hamilton                         273
# Robert Half                                 258
# Insight Global                              249
#                                            ...
# RedLight                                      1
# West Asset Management                         1
# Stylitics                                     1
# PetSmart                                      1
# Virginia Dept of Social Services - Local      1
# Name: count, Length: 7246, dtype: int64

# %%
jobs.groupby("company_name")["salary_year_avg"].agg(["min", "max", "mean"])
# Out:
#                                               min            max  \
# company_name
# #twiceasnice Recruiting              61000.000000  120000.000000
# /dev/color                          125000.000000  125000.000000
# 0nward Select                        92500.000000   92500.000000
# 1 Point System                      137290.484375  137290.484375
# 1 Point System LLC.                 170000.000000  170000.000000
# ...                                           ...            ...
# zooplus SE                          157500.000000  166000.000000
# ztp                                  95000.000000   95000.000000
# ЛАНИТ                               400000.000000  400000.000000
# Технологическая компания            280000.000000  280000.000000
# ​Illinois State Board of Education   62536.000000   62536.000000
#
#                                              mean
# company_name
# #twiceasnice Recruiting              77750.000000
# /dev/color                          125000.000000
# ...

# %%
jobs.groupby("job_location")["job_work_from_home"].count()
# Out:
# job_location
# A Coruña, Spain                    2
# Aarhus, Denmark                    1
# Abell, MD                          1
# Aberdeen Proving Ground, MD        4
# Aberdeen, MD                       7
#                                   ..
# Zwolle, Netherlands                2
# Zürich, Switzerland               14
# Zürich, Switzerland (+1 other)     1
# İstanbul, Türkiye                 12
# Łódź, Poland                       1
# Name: job_work_from_home, Length: 2052, dtype: int64

# %%
jobs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21707 entries, 0 to 21706
# Data columns (total 19 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Unnamed: 0             21707 non-null  int64
#  1   job_title_short        21707 non-null  object
#  2   job_title              21707 non-null  object
#  3   job_location           21707 non-null  object
#  4   job_via                21707 non-null  object
#  5   job_schedule_type      21707 non-null  object
#  6   job_work_from_home     21707 non-null  bool
#  7   search_location        21707 non-null  object
#  8   job_posted_date        21707 non-null  datetime64[ns]
#  9   job_no_degree_mention  21707 non-null  bool
#  10  job_health_insurance   21707 non-null  bool
#  11  job_country            21707 non-null  object
#  12  salary_rate            21707 non-null  object
#  13  salary_year_avg        21707 non-null  float64
# ...

# %%
jobs.groupby(["job_location", "job_title"])["salary_year_avg"].mean().head()
# Out:
# job_location                 job_title
# A Coruña, Spain              Cloud DevSecOps Engineer      125253.0
#                              Cloud SysSecOps Engineer       56700.0
# Aarhus, Denmark              Data Management Consultant     56700.0
# Abell, MD                    Senior Data Scientist         166075.0
# Aberdeen Proving Ground, MD  Data Scientist                160000.0
# Name: salary_year_avg, dtype: float64

# %%
industry_avg = jobs["salary_year_avg"].mean()

# %%
company = jobs.groupby("company_name")["salary_year_avg"].mean()

# %%
top_companies = company > industry_avg

# %%
print(top_companies)
# Out:
# company_name
# #twiceasnice Recruiting               False
# /dev/color                             True
# 0nward Select                         False
# 1 Point System                         True
# 1 Point System LLC.                    True
#                                       ...
# zooplus SE                             True
# ztp                                   False
# ЛАНИТ                                  True
# Технологическая компания               True
# ​Illinois State Board of Education    False
# Name: salary_year_avg, Length: 7246, dtype: bool

# %%
jobs.reset_index()
# Out:
#        index  Unnamed: 0 job_title_short  \
# 0          0          28  Data Scientist
# 1          1          77   Data Engineer
# 2          2          92   Data Engineer
# 3          3         100  Data Scientist
# 4          4         109    Data Analyst
# ...      ...         ...             ...
# 21702  21702      785624   Data Engineer
# 21703  21703      785641   Data Engineer
# 21704  21704      785648  Data Scientist
# 21705  21705      785682  Data Scientist
# 21706  21706      785692  Data Scientist
#
#                                                job_title  \
# 0                                    CRM Data Specialist
# 1                                          Data Engineer
# 2                Remote - Data Engineer - Permanent - W2
# 3                Data Scientist, Risk Data Mining - USDS
# 4                  Senior Supply Chain Analytics Analyst
# ...                                                  ...
# 21702                   Data Analytics Engineer (Hybrid)
# ...

# %%
null_values = jobs["salary_year_avg"].isnull()

# %%
null_values
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 21702    False
# 21703    False
# 21704    False
# 21705    False
# 21706    False
# Name: salary_year_avg, Length: 21707, dtype: bool
